# %% [markdown]
# # S1 Coding Lab — AI vs Automation
#
# ใช้เงื่อนไขเพื่อสร้างระบบตอบสนองแบบอัตโนมัติ และอภิปรายว่าเหตุใดระบบกฎอย่างเดียวอาจยังไม่ใช่ AI

# %% [markdown]
# ## Predict
# เมื่อ temperature = 38 โปรแกรมจะแสดงอะไร
#
# เขียนคำตอบก่อนรันโค้ด

# %%
temperature = 38

if temperature >= 37.5:
    print('High temperature alert')
else:
    print('Normal')

# %% [markdown]
# ## Modify
# เปลี่ยน threshold เป็น 38.5 และทดสอบค่า 38 กับ 39

# %%
# เขียนโค้ดที่แก้ไขแล้วตรงนี้

# %% [markdown]
# ## Challenge
# เพิ่มเงื่อนไข Low, Normal และ High อย่างน้อย 3 ระดับ

# %%
# Challenge solution

# %% [markdown]
# ## Explain
# อธิบายว่าโค้ดทำงานอย่างไร และผลลัพธ์เปลี่ยนเพราะอะไร

# %% [markdown]
# ## Reflection
# 1. สิ่งที่เข้าใจ
# 2. สิ่งที่ยังสับสน
# 3. การประยุกต์ใช้
# 4. ข้อจำกัดของแนวทางนี้
