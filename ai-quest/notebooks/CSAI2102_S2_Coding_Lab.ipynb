# %% [markdown]
# # S2 Coding Lab — Intelligent Agent
#
# Agent รับ percept แล้วเลือก action ตามกฎหรือ policy

# %% [markdown]
# ## Predict
# เมื่อ percept = dirty โปรแกรมจะแสดงอะไร
#
# เขียนคำตอบก่อนรันโค้ด

# %%
def agent(percept):
    if percept == 'dirty':
        return 'clean'
    return 'move'

print(agent('dirty'))

# %% [markdown]
# ## Modify
# เพิ่ม percept = obstacle แล้วให้ agent ตอบ turn

# %%
# เขียนโค้ดที่แก้ไขแล้วตรงนี้

# %% [markdown]
# ## Challenge
# เพิ่ม battery_low และ goal_found พร้อม action ที่เหมาะสม

# %%
# Challenge solution

# %% [markdown]
# ## Explain
# อธิบายว่าโค้ดทำงานอย่างไร และผลลัพธ์เปลี่ยนเพราะอะไร

# %% [markdown]
# ## Reflection
# 1. สิ่งที่เข้าใจ
# 2. สิ่งที่ยังสับสน
# 3. การประยุกต์ใช้
# 4. ข้อจำกัดของแนวทางนี้
