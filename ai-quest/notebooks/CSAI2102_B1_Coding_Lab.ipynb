# %% [markdown]
# # B1 Coding Boss — AI Foundations
#
# บูรณาการ AI vs Automation, Agent และ Search ในสถานการณ์เดียว

# %% [markdown]
# ## Predict
# Agent จะเลือก action ใดเมื่อ percept เป็น blocked
#
# เขียนคำตอบก่อนรันโค้ด

# %%
from collections import deque

def choose_action(percept):
    if percept == 'blocked':
        return 'search_new_route'
    return 'move_forward'

print(choose_action('blocked'))

# %% [markdown]
# ## Modify
# เพิ่ม percept อีก 2 แบบและ action ที่สมเหตุสมผล

# %%
# เขียนโค้ดที่แก้ไขแล้วตรงนี้

# %% [markdown]
# ## Challenge
# เชื่อม agent เข้ากับ BFS เพื่อค้นหาเส้นทางใหม่เมื่อ blocked

# %%
# Challenge solution

# %% [markdown]
# ## Explain
# อธิบายว่าโค้ดทำงานอย่างไร และผลลัพธ์เปลี่ยนเพราะอะไร

# %% [markdown]
# ## Reflection
# 1. สิ่งที่เข้าใจ
# 2. สิ่งที่ยังสับสน
# 3. การประยุกต์ใช้
# 4. ข้อจำกัดของแนวทางนี้
